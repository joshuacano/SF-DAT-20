# %%
# usual imports
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


# %matplotlib notebook

from sklearn.cross_validation import train_test_split

# Each is a different implemntation of a text transform tool: Bag of Words & Tfidf
from sklearn.feature_extraction.text import CountVectorizer,TfidfVectorizer

# %%
rows = []
with open('/Users/jcano/src/repos/SF-DAT-20/Data/amazon_cells_labelled.txt') as f:
    ka = f.readlines()
    for i,line in enumerate(f.readlines()):
        row = (line.split('\n')[0]).split('\t')
        #if len(line.split("\n")) > 1:
            #print line.split("\n")
        if row[1] == '':
            row[1] = np.nan
        else:
            row[1] = int(row[1])
        rows.append(row)
# Out:
# So there is no way for me to plug it in here in the US unless I go by a converter.	0

# %%
Amazon_data = pd.DataFrame(rows,columns=['text','sentiment'])
Amazon_data.head()
Amazon_data.count()
# Out:
# text         15004
# sentiment     1000
# dtype: int64

# %%
Amazon_data.dropna(inplace = True)
Amazon_data.head()
Amazon_data.describe()
# Out:
#         sentiment
# count  1000.00000
# mean      0.50000
# std       0.50025
# min       0.00000
# 25%       0.00000
# 50%       0.50000
# 75%       1.00000
# max       1.00000

# %% [markdown]
# The data is sentiment on Amazon reviews! But in order to use it we need to create a feature space. Please review the documentation for these functions:
#
# http://scikit-learn.org/stable/modules/generated/sklearn.feature_extraction.text.CountVectorizer.html
# You'll see that we have a ton of options available. I'll start out with the simplest default.

# %%
count_vect = CountVectorizer(stop_words='english')
bag_o_words = count_vect.fit_transform(Amazon_data['text'])
bag_o_words
# Out:
# <1000x1642 sparse matrix of type '<type 'numpy.int64'>'
# 	with 4702 stored elements in Compressed Sparse Row format>

# %% [markdown]
# Dense matrices store every entry in the matrix. Sparse matrices only store the nonzero entries. Sparse matrices don't have a lot of extra features, and some algorithms may not work for them. You use them when you need to work with matrices that would be too big for the computer to handle them, but they are mostly zero, so they compress easily. You can convert to dense matrices with .todense( )

# %%
# bag_o_words.todense()
count_vect.get_feature_names()
# Out:
# [u'10',
#  u'100',
#  u'11',
#  u'12',
#  u'13',
#  u'15',
#  u'15g',
#  u'18',
#  u'20',
#  u'2000',
#  u'2005',
#  u'2160',
#  u'24',
#  u'2mp',
#  u'325',
#  u'350',
#  u'375',
#  u'3o',
#  u'42',
#  u'44',
#  u'45',
#  u'4s',
#  u'50',
#  u'5020',
#  u'510',
#  u'5320',
#  u'680',
#  u'700w',
#  u'8125',
#  u'8525',
#  u'8530',
#  u'abhor',
#  u'ability',
#  u'able',
#  u'abound',
#  u'absolutel',
#  u'absolutely',
#  u'ac',
#  u'accept',
#  u'acceptable',
#  u'access',
#  u'accessable',
#  u'accessing',
#  u'accessory',
#  u'accessoryone',
#  u'accidentally',
#  u'accompanied',
#  u'according',
#  u'activate',
#  u'activated',
#  u'activesync',
#  u'actually',
#  u'ad',
#  u'adapter',
#  u'adapters',
#  u'add',
#  u'addition',
#  u'additional',
#  u'address',
#  u'adhesive',
#  u'adorable',
#  u'advertised',
#  u'advise',
#  u'aggravating',
#  u'ago',
#  u'alarm',
#  u'allot',
#  u'allow',
#  u'allowing',
#  u'allows',
#  u'alot',
#  u'aluminum',
#  u'amazed',
#  u'amazing',
#  u'amazon',
#  u'amp',
#  u'ample',
#  u'angeles',
#  u'angle',
#  u'answer',
#  u'ant',
#  u'antena',
#  u'anti',
#  u'apart',
#  u'apartment',
#  u'apparently',
#  u'appealing',
#  u'appearance',
#  u'appears',
#  u'applifies',
#  u'appointments',
#  u'area',
#  u'arguing',
#  u'armband',
#  u'arrival',
#  u'arrived',
#  u'asia',
#  u'ask',
#  u'aspect',
#  u'assumed',
#  u'atleast',
#  u'att',
#  u'attacked',
#  u'attractive',
#  u'audio',
#  u'authentic',
#  u'auto',
#  u'available',
#  u'average',
#  u'avoid',
#  u'avoiding',
#  u'away',
#  u'awesome',
#  u'awful',
#  u'awkward',
#  u'awsome',
#  u'background',
#  u'backlight',
#  u'bad',
#  u'balance',
#  u'bar',
#  u'barely',
#  u'bargain',
#  u'bars',
#  u'basement',
#  u'basic',
#  u'basically',
#  u'batteries',
#  u'battery',
#  u'beat',
#  u'beats',
#  u'beautiful',
#  u'bed',
#  u'beep',
#  u'beeping',
#  u'behing',
#  u'believe',
#  u'bells',
#  u'belt',
#  u'bend',
#  u'best',
#  u'better',
#  u'beware',
#  u'big',
#  u'biggest',
#  u'bills',
#  u'bit',
#  u'bitpim',
#  u'black',
#  u'blackberry',
#  u'blacktop',
#  u'bland',
#  u'blew',
#  u'blue',
#  u'blueant',
#  u'bluetoooth',
#  u'bluetooth',
#  u'bluetooths',
#  u'bmw',
#  u'book',
#  u'booking',
#  u'boost',
#  u'boot',
#  u'bose',
#  u'bother',
#  u'bottowm',
#  u'bought',
#  u'bougth',
#  u'boy',
#  u'brand',
#  u'break',
#  u'breakage',
#  u'breaking',
#  u'breaks',
#  u'brilliant',
#  u'broke',
#  u'broken',
#  u'browser',
#  u'browsing',
#  u'bt',
#  u'bt250v',
#  u'bt50',
#  u'bubbling',
#  u'bucks',
#  u'buds',
#  u'build',
#  u'built',
#  u'bulky',
#  u'bumpers',
#  u'button',
#  u'buttons',
#  u'buy',
#  u'buyer',
#  u'buyers',
#  u'buying',
#  u'buyit',
#  u'buzzing',
#  u'ca',
#  u'cable',
#  u'cables',
#  u'calendar',
#  u'called',
#  u'calls',
#  u'came',
#  u'camera',
#  u'canal',
#  u'cancellation',
#  u'cancelling',
#  u'capability',
#  u'capacity',
#  u'car',
#  u'card',
#  u'care',
#  u'careful',
#  u'carried',
#  u'carriers',
#  u'carries',
#  u'carry',
#  u'case',
#  u'cases',
#  u'casing',
#  u'cassette',
#  u'cat',
#  u'catching',
#  u'caused',
#  u'causing',
#  u'cbr',
#  u'cds',
#  u'cell',
#  u'cellphone',
#  u'cellphones',
#  u'cellular',
#  u'cent',
#  u'center',
#  u'certain',
#  u'certainly',
#  u'changing',
#  u'channel',
#  u'charge',
#  u'charged',
#  u'charger',
#  u'chargers',
#  u'charges',
#  u'charging',
#  u'charm',
#  u'cheap',
#  u'cheaper',
#  u'cheaply',
#  u'cheapy',
#  u'check',
#  u'checked',
#  u'child',
#  u'china',
#  u'chinese',
#  u'choice',
#  u'choices',
#  u'christmas',
#  u'cingulair',
#  u'cingular',
#  u'clarity',
#  u'classy',
#  u'clear',
#  u'clearer',
#  u'clearly',
#  u'clever',
#  u'clicks',
#  u'clip',
#  u'clipping',
#  u'clips',
#  u'clock',
#  u'colleague',
#  u'color',
#  u'colored',
#  u'colors',
#  u'combination',
#  u'come',
#  u'comes',
#  u'comfort',
#  u'comfortable',
#  u'comfortably',
#  u'comfortible',
#  u'coming',
#  u'comments',
#  u'commercials',
#  u'communicate',
#  u'communication',
#  u'communications',
#  u'commuter',
#  u'company',
#  u'comparably',
#  u'compared',
#  u'compete',
#  u'competitors',
#  u'complain',
#  u'complained',
#  u'complaint',
#  u'complaints',
#  u'completely',
#  u'compliments',
#  u'compromise',
#  u'computer',
#  u'concrete',
#  u'conditions',
#  u'confortable',
#  u'confusing',
#  u'connect',
#  u'connected',
#  u'connecting',
#  u'connection',
#  u'constantly',
#  u'constructed',
#  u'construction',
#  u'consumer',
#  u'contact',
#  u'contacted',
#  u'contacting',
#  u'contacts',
#  u'continue',
#  u'continues',
#  u'contract',
#  u'control',
#  u'controls',
#  u'contstruct',
#  u'convenient',
#  u'conversation',
#  u'conversations',
#  u'converter',
#  u'cool',
#  u'copier',
#  u'copy',
#  u'corded',
#  u'correctly',
#  u'cost',
#  u'costs',
#  u'couldn',
#  u'counter',
#  u'counterfeit',
#  u'couple',
#  u'coupon',
#  u'course',
#  u'cover',
#  u'coverage',
#  u'covered',
#  u'crack',
#  u'cracked',
#  u'cradle',
#  u'cradles',
#  u'crap',
#  u'crappy',
#  u'crashed',
#  u'crawl',
#  u'creaks',
#  u'crisp',
#  u'cumbersome',
#  u'current',
#  u'currently',
#  u'curve',
#  u'customer',
#  u'cut',
#  u'cute',
#  u'cutouts',
#  u'cuts',
#  u'd807',
#  u'damage',
#  u'darn',
#  u'data',
#  u'date',
#  u'day',
#  u'days',
#  u'dead',
#  u'deaf',
#  u'deal',
#  u'decade',
#  u'decent',
#  u'decision',
#  u'defeats',
#  u'defect',
#  u'defective',
#  u'deffinitely',
#  u'definitely',
#  u'definitly',
#  u'delay',
#  u'delivery',
#  u'described',
#  u'description',
#  u'design',
#  u'designed',
#  u'designs',
#  u'despite',
#  u'destination',
#  u'destroying',
#  u'detachable',
#  u'detailed',
#  u'development',
#  u'device',
#  u'devices',
#  u'dialing',
#  u'did',
#  u'didn',
#  u'died',
#  u'dieing',
#  u'different',
#  u'difficult',
#  u'directed',
#  u'directions',
#  u'directly',
#  u'dirty',
#  u'disapoinment',
#  u'disapointing',
#  u'disappoint',
#  u'disappointed',
#  u'disappointing',
#  u'disappointment',
#  u'discarded',
#  u'discomfort',
#  u'disconnected',
#  u'discount',
#  u'disgusting',
#  u'display',
#  u'displeased',
#  u'disposable',
#  u'dissapointed',
#  u'dissapointing',
#  u'distorted',
#  u'distracting',
#  u'dit',
#  u'division',
#  u'dna',
#  u'docking',
#  u'does',
#  u'doesn',
#  u'doing',
#  u'dollar',
#  u'don',
#  u'dont',
#  u'double',
#  u'download',
#  u'downloading',
#  u'dozen',
#  u'dozens',
#  u'drain',
#  u'drained',
#  u'drains',
#  u'drawback',
#  u'driving',
#  u'drivng',
#  u'droid',
#  u'drop',
#  u'dropped',
#  u'dropping',
#  u'drops',
#  u'dual',
#  u'durable',
#  u'dustpan',
#  u'dying',
#  u'e2',
#  u'e715',
#  u'ear',
#  u'earbud',
#  u'earbuds',
#  u'earbugs',
#  u'eargels',
#  u'earlier',
#  u'earpad',
#  u'earphone',
#  u'earphones',
#  u'earpiece',
#  u'earpieces',
#  u'ears',
#  u'earset',
#  u'ease',
#  u'easier',
#  u'easily',
#  u'easy',
#  u'echo',
#  u'edge',
#  u'effect',
#  u'effective',
#  u'effects',
#  u'effort',
#  u'electronics',
#  u'elegant',
#  u'embarassing',
#  u'embarrassing',
#  u'embedded',
#  u'encourage',
#  u'end',
#  u'ended',
#  u'ends',
#  u'engineered',
#  u'enjoy',
#  u'enter',
#  u'entertainment',
#  u'entire',
#  u'env',
#  u'equipment',
#  u'era',
#  u'ergonomic',
#  u'ericson',
#  u'ericsson',
#  u'especially',
#  u'essentially',
#  u'europe',
#  u'eventually',
#  u'everyday',
#  u'exactly',
#  u'exceeds',
#  u'excelent',
#  u'excellent',
#  u'excels',
#  u'exceptional',
#  u'excessive',
#  u'exchange',
#  u'exchanged',
#  u'excited',
#  u'exclaim',
#  u'excrutiatingly',
#  u'exercise',
#  u'existing',
#  u'expect',
#  u'expectations',
#  u'expected',
#  u'expensive',
#  u'experience',
#  u'experienced',
#  u'explain',
#  u'extended',
#  u'exterior',
#  u'external',
#  u'extra',
#  u'extremely',
#  u'eye',
#  u'fabulous',
#  u'face',
#  u'faceplates',
#  u'fact',
#  u'factor',
#  u'failed',
#  u'fails',
#  u'fairly',
#  u'fall',
#  u'falling',
#  u'falls',
#  u'family',
#  u'fantastic',
#  u'far',
#  u'fast',
#  u'faster',
#  u'father',
#  u'favorite',
#  u'feature',
#  u'features',
#  u'fee',
#  u'feel',
#  u'feels',
#  u'feet',
#  u'felt',
#  u'fi',
#  u'figure',
#  u'file',
#  u'finally',
#  u'finds',
#  u'fine',
#  u'fingers',
#  u'finished',
#  u'fit',
#  u'fits',
#  u'fixes',
#  u'flash',
#  u'flaw',
#  u'flawed',
#  u'flawless',
#  u'flawlessly',
#  u'flaws',
#  u'flimsy',
#  u'flip',
#  u'flipphones',
#  u'fliptop',
#  u'floor',
#  u'floppy',
#  u'flops',
#  u'flush',
#  u'fm',
#  u'followed',
#  u'fond',
#  u'fooled',
#  u'forced',
#  u'forever',
#  u'forgeries',
#  u'forget',
#  u'forgot',
#  u'form',
#  u'fourth',
#  u'fraction',
#  u'free',
#  u'freedom',
#  u'freeway',
#  u'freezes',
#  u'frequently4',
#  u'frequentyly',
#  u'friendly',
#  u'friends',
#  u'frog',
#  u'frustration',
#  u'fry',
#  u'ft',
#  u'fulfills',
#  u'fully',
#  u'fun',
#  u'function',
#  u'functional',
#  u'functionality',
#  u'functions',
#  u'funny',
#  u'gadget',
#  u'gadgets',
#  u'games',
#  u'garbage',
#  u'garbled',
#  u'gave',
#  u'geeky',
#  u'gels',
#  u'generally',
#  u'gentle',
#  u'genuine',
#  u'gets',
#  u'getting',
#  u'gimmick',
#  u'girl',
#  u'given',
#  u'giving',
#  u'glad',
#  u'glare',
#  u'glasses',
#  u'glove',
#  u'glued',
#  u'goes',
#  u'going',
#  u'gonna',
#  u'good',
#  u'good7',
#  u'gosh',
#  u'got',
#  u'gotten',
#  u'graphics',
#  u'great',
#  u'greater',
#  u'grey',
#  u'grip',
#  u'grtting',
#  u'guess',
#  u'gx2',
#  u'h500',
#  u'hair',
#  u'hand',
#  u'handheld',
#  u'hands',
#  u'handset',
#  u'handsfree',
#  u'handy',
#  u'happened',
#  u'happening',
#  u'happens',
#  u'happier',
#  u'happy',
#  u'hard',
#  u'hardly',
#  u'hat',
#  u'hate',
#  u'hated',
#  u'haul',
#  u'haven',
#  u'having',
#  u'headbands',
#  u'headphones',
#  u'headset',
#  u'headsets',
#  u'hear',
#  u'hearing',
#  u'heavy',
#  u'help',
#  u'helpful',
#  u'hey',
#  u'high',
#  u'highest',
#  u'highly',
#  u'highy',
#  u'hinge',
#  u'hit',
#  u'hitch',
#  u'hold',
#  u'holder',
#  u'holding',
#  u'holds',
#  u'holster',
#  u'home',
#  u'hook',
#  u'hoped',
#  u'hoping',
#  u'horrible',
#  u'hot',
#  u'hour',
#  u'hours',
#  u'hoursthe',
#  u'house',
#  u'hs850',
#  u'huge',
#  u'humans',
#  u'humming',
#  u'hurt',
#  u'hybrid',
#  u'hype',
#  u'iam',
#  u'idea',
#  u'ideal',
#  u'igo',
#  u'ill',
#  u'im',
#  u'imac',
#  u'images',
#  u'imagine',
#  u'immediately',
#  u'important',
#  u'impossible',
#  u'impressed',
#  u'impressive',
#  u'improper',
#  u'improve',
#  u'improvement',
#  u'inches',
#  u'included',
#  u'incoming',
#  u'inconspicuous',
#  u'increase',
#  u'incrediable',
#  u'incredible',
#  u'incredibly',
#  u'indoors',
#  u'industrial',
#  u'inexcusable',
#  u'inexpensive',
#  u'infatuated',
#  u'inform',
#  u'infra',
#  u'infuriating',
#  u'insert',
#  u'inside',
#  u'install',
#  u'installed',
#  u'instance',
#  u'instead',
#  u'instruction',
#  u'instructions',
#  u'integrated',
#  u'intended',
#  u'interested',
#  u'interface',
#  u'intermittently',
#  u'internet',
#  u'invented',
#  u'investment',
#  u'iphone',
#  u'ipod',
#  u'ipods',
#  u'ir',
#  u'irda',
#  u'iriver',
#  u'isn',
#  u'issues',
#  u'item',
#  u'items',
#  u'jabra',
#  u'jabra350',
#  u'jack',
#  u'jawbone',
#  u'jerks',
#  u'jiggle',
#  u'job',
#  u'joke',
#  u'joy',
#  u'juice',
#  u'junk',
#  u'just',
#  u'jx',
#  u'keen',
#  u'keeping',
#  u'keeps',
#  u'kept',
#  u'key',
#  u'keyboard',
#  u'keypad',
#  u'keypads',
#  u'keys',
#  u'killer',
#  u'kind',
#  u'kindle',
#  u'kitchen',
#  u'kits',
#  u'knock',
#  u'know',
#  u'knows',
#  u'krussel',
#  u'l7c',
#  u'lacking',
#  u'land',
#  u'lap',
#  u'laptop',
#  u'large',
#  u'lasted',
#  u'lasting',
#  u'lasts',
#  u'latch',
#  u'lately',
#  u'later',
#  u'latest',
#  u'laughing',
#  u'leaf',
#  u'leaks',
#  u'learned',
#  u'leather',
#  u'left',
#  u'lense',
#  u'leopard',
#  u'lesson',
#  u'let',
#  u'letting',
#  u'lg',
#  u'life',
#  u'light',
#  u'lightly',
#  u'lights',
#  u'lightweight',
#  u'like',
#  u'liked',
#  u'likes',
#  u'line',
#  u'linked',
#  u'linking',
#  u'linksys',
#  u'listener',
#  u'listening',
#  u'lit',
#  u'literally',
#  u'little',
#  u'living',
#  u'll',
#  u'loads',
#  u'lock',
#  u'locked',
#  u'locks',
#  u'logitech',
#  u'long',
#  u'longer',
#  u'look',
#  u'looking',
#  u'looks',
#  u'loop',
#  u'loops',
#  u'loose',
#  u'looses',
#  u'los',
#  u'lose',
#  u'lost',
#  u'lot',
#  u'lots',
#  u'loud',
#  u'louder',
#  u'loudest',
#  u'loudspeaker',
#  u'lousy',
#  u'love',
#  u'loved',
#  u'loves',
#  u'low',
#  u'luck',
#  u'machine',
#  u'magical',
#  u'magnetic',
#  u'mail',
#  u'mainly',
#  u'maintain',
#  u'maintains',
#  u'major',
#  u'majority',
#  u'make',
#  u'makes',
#  u'making',
#  u'managed',
#  u'management',
#  u'manual',
#  u'manufacturer',
#  u'mark',
#  u'market',
#  u'match',
#  u'material',
#  u'max',
#  u'means',
#  u'mechanism',
#  u'media',
#  u'mediocre',
#  u'mega',
#  u'megapixels',
#  u'memory',
#  u'mention',
#  u'mentioned',
#  u'menus',
#  u'mere',
#  u'mess',
#  u'message',
#  u'messages',
#  u'messaging',
#  u'messes',
#  u'metal',
#  u'metro',
#  u'mic',
#  u'microphone',
#  u'microsoft',
#  u'mind',
#  u'mini',
#  u'mins',
#  u'minute',
#  u'minutes',
#  u'misleading',
#  u'missed',
#  u'mistake',
#  u'mobile',
#  u'mode',
#  u'model',
#  u'modest',
#  u'money',
#  u'monkeys',
#  u'month',
#  u'months',
#  u'morning',
#  u'mother',
#  u'moto',
#  u'motor',
#  u'motorola',
#  u'motorolas',
#  u'moving',
#  u'mp3',
#  u'mp3s',
#  u'muddy',
#  u'muffled',
#  u'multiple',
#  u'music',
#  u'mute',
#  u'nano',
#  u'navigate',
#  u'near',
#  u'nearly',
#  u'neat',
#  u'need',
#  u'needed',
#  u'needless',
#  u'needs',
#  u'negatively',
#  u'network',
#  u'new',
#  u'ngage',
#  u'nice',
#  u'nicely',
#  u'nicer',
#  u'night',
#  u'nightmare',
#  u'noise',
#  u'noises',
#  u'nokia',
#  u'normal',
#  u'normally',
#  u'note',
#  u'noted',
#  u'notice',
#  u'noticed',
#  u'number',
#  u'numbers',
#  u'numerous',
#  u'nyc',
#  u'obviously',
#  u'occupied',
#  u'odd',
#  u'oem',
#  u'offering',
#  u'offers',
#  u'official',
#  u'oh',
#  u'ok',
#  u'old',
#  u'ones',
#  u'online',
#  u'oozes',
#  u'open',
#  u'opens',
#  u'operate',
#  u'operates',
#  u'optimal',
#  u'option',
#  u'options',
#  u'order',
#  u'ordered',
#  ...]

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.cross_validation import cross_val_score
X = bag_o_words
y = Amazon_data['sentiment']
Features = [10,20,50,70,80,90,100,150,200,300,400,500,600,700,1000]
Scores_cv = []
for i in Features:
    RF = RandomForestClassifier(n_estimators = 100, #Number of trees - the more the better!
                           max_features = i,     #How many features to randomly choose in each node 
                           min_samples_leaf = 5, #Minimum number of observations at each terminal node
                           oob_score = True)

    print i
    RF.fit(X,y)
    scores = cross_val_score(RF, X, y, cv=5)
    Scores_cv.append(scores.mean())
    print(scores.mean())

Depth_Choice_df = pd.DataFrame({'CV_SCORE': Scores_cv ,'Number of Features': Features})
Depth_Choice_df.plot(x ='Number of Features',y = 'CV_SCORE' )
# Out:
# 10
# 0.667
# 20
# 0.703
# 50
# 0.756
# 70
# 0.756
# 80
# 0.763
# 90
# 0.762
# 100
# 0.759
# 150
# 0.769
# 200
# 0.767
# 300
# 0.759
# 400
# 0.762
# 500
# 0.762
# 600
# 0.762
# 700
# 0.753
# 1000
# 0.756
# <img src="data:image/png;base64,...">

# %% [markdown]
# # GridSearchCV and Pipeline Great tools that all data scientists enjoy using!

# %%
from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestClassifier
from sklearn.grid_search import GridSearchCV

# %%
from sklearn.cross_validation import train_test_split
from sklearn.metrics import classification_report
# Resetting our data
X_train,X_test,y_train,y_test = train_test_split(Amazon_data['text'],Amazon_data['sentiment'],test_size=0.2)

# %%
text_clf = Pipeline([('vect', CountVectorizer()),
                     ('clf', RandomForestClassifier())])

# %% [markdown]
# You can set both parameters of your classification algorithm and parameters of CountVectorizer(). Couple of points to remember:
#
# 1. You cannot use parameters that contradict each other. For example if min and max do not match you will see an error.
# 2. It is harder to find out contradiction of two different parameters. For example if you set maximum_feature in random forest to 50 but max_df in vect is 30, then you will have an error.
# 3. It seems like for classification problems, you can only use algorithms that work with probability. If your algorithm works with Loss functions then you cannot use GridSearchCV. Particularly, it seems like Gradiant Boosting Trees cannot be used in GridSearchCV. A few algorithms that can be used in GridSearchCV are: logistic regression,  random forest and Naive Bayes.

# %%
parameters = {'vect__min_df':[1,2,3],
              'vect__max_df':[5,10,100,200,500,1000],
              'clf__n_estimators':[1000]}

gs_clf = GridSearchCV(text_clf, parameters, n_jobs=2)

# %%
fit_grid = gs_clf.fit(X_train,y_train)

# %%
fit_grid.score(X_test,y_test)
# Out:
# 0.73999999999999999

# %%
fit_grid.best_params_
# Out:
# {'clf__n_estimators': 1000, 'vect__max_df': 100, 'vect__min_df': 1}

# %% [markdown]
# #### Now let's try TfidVectorizer

# %%
text_clf = Pipeline([('vect', TfidfVectorizer()),
                     ('clf', RandomForestClassifier()) ])
parameters = {'vect__min_df':[1,5,10],
              'vect__max_df':[15,50,100,200,500,1000],
              'clf__n_estimators':[1000]}

gs_clf = GridSearchCV(text_clf, parameters, n_jobs=2)

# %%
fit_grid = gs_clf.fit(X_train,y_train)

# %%
fit_grid.score(X_test,y_test)
# Out:
# 0.755

# %%
fit_grid.best_params_
# Out:
# {'clf__n_estimators': 1000, 'vect__max_df': 100, 'vect__min_df': 1}
